# %% [markdown]
# # 04-matplotlib-viz
#
# **CS Quests project notebook**
#
# This notebook accompanies the project lesson. Use it to experiment with the code examples from the website.
#
# [Return to the lesson page](../uv/04-matplotlib-viz.qmd)

# %%
# Start here
print("Welcome to the project notebook for 04-matplotlib-viz!")
print("Use this notebook to try the examples from the lesson page.")
